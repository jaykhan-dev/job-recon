# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import datetime
import requests
from bs4 import BeautifulSoup
import urllib.request
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
df = pd.read_csv('Applications.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 119 non-null    datetime64[ns]
#  1   Job Title            121 non-null    object
#  2   Company              125 non-null    object
#  3   Region               120 non-null    object
#  4   Timezone             41 non-null     object
#  5   Website              53 non-null     object
#  6   Email                5 non-null      object
#  7   Industry             103 non-null    object
#  8   Software Stack       112 non-null    object
#  9   Point of Interest    116 non-null    object
#  10  Relevant Experience  111 non-null    object
#  11  Discovery            115 non-null    object
#  12  STATUS               11 non-null     object
#  13  COMMENTS             27 non-null     object
#  14  RESUME               70 non-null     object
# ...

# %%
nov_applied = '''SELECT * FROM df WHERE Date BETWEEN "2021-11-01" AND "2021-11-29" '''
nov_get = pysqldf(nov_applied)
print(len(nov_get))
# Out:
# 44

# %%
dec_applied = '''SELECT * FROM df WHERE Date BETWEEN "2021-12-01" AND "2021-12-31" '''
dec_get = pysqldf(dec_applied)
print(len(dec_get))
# Out:
# 28

# %%
jan_applied = '''SELECT * FROM df WHERE Date BETWEEN "2022-01-01" AND "2022-01-31" '''
jan_get = pysqldf(jan_applied)
print(len(jan_get))
# Out:
# 18

# %%
feb_applied = '''SELECT * FROM df WHERE Date BETWEEN "2022-02-01" AND "2022-02-28" '''
feb_get = pysqldf(feb_applied)
print(len(feb_get))
# Out:
# 25

# %%
by_month_nums= [
    ['NOV', 44],
    ['DEC', 28],
    ['JAN', 18],
    ['FEB', 25],
]
month_bar_chart = pd.DataFrame(by_month_nums, columns=['Month', 'Applications'])
month_bar_chart.plot(x='Month', y=['Applications'], kind='bar', figsize=(10, 9))
plt.show()

# %% [markdown]
# # Keywords Strategy
#
# Having a vision and a clear goal will bring results.
#
# ## Role: UI/UX Developer
#
# My experience and interests line up with this more because I can use any tool at my disposal to get the job done.  Whether it's Webflow, Figma, WordPress, Django, or VueJs, they all follow the same basic web and software principles.
#
# ## Industry: Blockchain
#
# There are several streams to consider:
# - NFT websites
# - Smart Contracts programming
# - UI/UX
# - Writing Articles
#
# ### Tactics:
# - Start with "Blockchain" on all platforms first because what you want is what you will attract.
# - The easiest part for me might be SQL and data analysis because it's familiar territory, rather than smart contracts due to the complexity and experience required.
#
# ### Research:

# %%
blockchain_query = '''SELECT * FROM df WHERE Industry = "Blockchain";'''
blockchain_get = pysqldf(blockchain_query)
print(len(blockchain_get))
# Out:
# 17

# %%
search_keywords = [
    'Blockchain',
    'Crypto',
    'uiux',
    'graphic design',
    'landing page',
    'web designer',
    'web developer',
    'vue developer',
    'front-end developer',
    'back-end developer',
    'pyteal',
    'sql',
]

job_boards = [
    'remotive.io',
    'remoteleads.io',
    'remoteok.io',
    'angel.co/jobs',
    'justremote.co',
    'weworkremotely.com',
    'javascriptjob.xyz',
    'flexjobs.com',
    'solidgigs',
    'dynamitejobs.com',
    'indeed',
    'linkedin',
    'cryptocurrencyjobs',
    'upwork',
]

software_by_industry = {
    "Web development": ["Vue", "Tailwind", "UI/UX"],
    "Blockchain": ["PyTEAL", "Algorand", "ASA"], #Once I get more comfortable with 
    "Data Analysis": ["Pandas", "SQL", "Jupyter"]
}
keywords_df = pd.DataFrame.from_dict(software_by_industry)
keywords_df
# Out:
#   Web development Blockchain Data Analysis
# 0             Vue     PyTEAL        Pandas
# 1        Tailwind   Algorand           SQL
# 2           UI/UX        ASA       Jupyter

# %% [markdown]
# # Reconnaissance
#
# ## GET which Blockchains are listed in the requirements
# ## GET NFT website reqs
# ## GET

# %%
discovery_query = '''SELECT DISTINCT Discovery FROM df;'''
discovery_get = pysqldf(discovery_query)
print(discovery_get)
# Out:
#                 Discovery
# 0                Linkedin
# 1              CryptoJobs
# 2                  Upwork
# 3                  Indeed
# 4                LinkedIn
# 5         Linkedin/Indeed
# 6                    None
# 7         Indeed/Linkedin
# 8                     WWR
# 9                Remotive
# 10              Jobillico
# 11           Ziprecruiter
# 12                 UPwork
# 13                 upwork
# 14                 Talent
# 15                     Up
# 16  cryptocurrencyjobs.co
